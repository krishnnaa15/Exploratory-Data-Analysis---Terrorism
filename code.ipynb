# %% [markdown]
# # Exploratory Data Analysis - Global Terrorism

# %% [markdown]
# ### Terrorism
#
# Terrorism is the unlawful use of force or violence against persons or property to intimidate a government or its citizens to further certain political or social objectives.

# %% [markdown]
# ### Project Outlook
#
# + Selecting a real-world dataset
# + Performing Data Cleaning and Structuring For Analysis
# + Performing Data Analysis With Graphical Visualization
# + Sumarizing the Insights gathered from the dataset and Conclusions

# %% [markdown]
# ### Selecting a Real- World Dataset
#
# In this project we are using the "GLOBAL TERRORISM DATASET" that contains aprrox 180k of Terrorist activity reported under the time frame of 47 years that is from 1970 till 2017.
#
# The dataset have 135 different informative parameters under which an activity has been reported.
# These are - **Date, Country, State, Region, Number of people Killed, Terrorist group responsible for the attack, Attack types** etc.
#
# **Dataset: https://bit.ly/2TK5Xn5**

# %% [markdown]
# ### Importing all the libraries required for analysis#

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# This code imports four Python packages - ***NumPy, Seaborn, Pandas, Matplotlib.pyplot***
#
# + **NumPy** is a package for scientific computing with Python, and it provides support for arrays and matrices, as well as mathematical functions to manipulate these arrays.
#
# + **Seaborn** is a data visualization library based on Matplotlib, which provides additional functionality and a more user-friendly interface.
#
# + **Pandas** is a data manipulation library that provides tools to read, write, and analyze data in various formats, including CSV, Excel, SQL, and more.
#
# + **Matplotlib** is a data visualization library for Python, and Pyplot is a module within Matplotlib that provides a MATLAB-like interface for creating plots and charts.

# %% [markdown]
# ### Importing the data

# %%
data=pd.read_csv("globalterrorismdb_0718dist.csv", encoding="latin1")
df=pd.DataFrame(data)
print("Data has been successfully imported")
df.head()
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_11348\3748511756.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("globalterrorismdb_0718dist.csv", encoding="latin1")
# Data has been successfully imported
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
# info() is a pandas function that prints information about the DataFrame

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
# Representing the dimensions of the DataFrame [ie.. (row,column)]

df.shape
# Out:
# (181691, 135)

# %%
# Returns all column names as a list

df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
# Prints each column name followed by a comma 

for i in df.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %% [markdown]
# ### Cleaning the data

# %%
# select specific columns from the DataFrame df and create a new DataFrame with only those columns 

df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
# Rename the columns in the DataFrame

df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)

# %%
# Display the first few rows of your DataFrame with the new column names

df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
# provides a concise summary of the DataFrame, including information about the data types of each column, the number of non-null values, and memory usage

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %%
# Representing the dimensions of the DataFrame [ie.. (row,column)]

df.shape
# Out:
# (181691, 19)

# %%
# Count the number of missing values in each column of the DataFrame

df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            4556
# Longitude           4557
# Location          126196
# Summary            66129
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            131130
# Weapon Type            0
# Killed             10313
# Wounded            16311
# Add Notes         153402
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)
df["Casualty"]=df["Killed"]+df["Wounded"]

# %% [markdown]
# This above code fills any missing values in the **Killed** and **Wounded** columns with zeros using the **fillna(0)** method and then creates a new column "**Casualty** by adding the values of **Killed** and **Wounded** together. The resulting DataFrame will have the new **Casualty** column with the total casualties.

# %%
"""
Used to generate descriptive statistics of the numerical columns in a DataFrame.It provides 
information such as the count, mean, standard deviation, minimum, 25th percentile (Q1), median
(50th percentile or Q2), 75th percentile (Q3), and maximum.
"""

df.describe()
# Out:
#                 Year          Month            Day       Latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean     2002.638997       6.467277      15.505644      23.498343
# std        13.259430       3.388303       8.814045      18.569242
# min      1970.000000       0.000000       0.000000     -53.154613
# 25%      1991.000000       4.000000       8.000000      11.510046
# 50%      2009.000000       6.000000      15.000000      31.467463
# 75%      2014.000000       9.000000      23.000000      34.685087
# max      2017.000000      12.000000      31.000000      74.633553
#
#           Longitude         Killed        Wounded       Casualty
# count  1.771340e+05  181691.000000  181691.000000  181691.000000
# mean  -4.586957e+02       2.266860       2.883296       5.150156
# std    2.047790e+05      11.227057      34.309747      40.555416
# min   -8.618590e+07       0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# ***1. Year wise attacks***

# %% [markdown]
# + Number of attacks in each year

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Out:
#       Attacks
# Year
# 1970      651
# 1971      471
# 1972      568
# 1973      473
# 1974      581

# %% [markdown]
# ***We are trying to count the number of attacks per year.***
#
# In this code:
#
# + **df["Year"].value_counts(dropna=False)** - counts the occurrences of each unique value in the "Year" column.
# + **.sort_index()** - sorts the values by the index (in this case, the years).
# + **.to_frame()** - converts the result into a DataFrame.
# + **.reset_index()** - resets the index and moves the current index (years) to a new column.
# + **rename(columns={"index": "Year", "Year": "Attacks"})** - renames the columns to "Year" and "Attacks".

# %%
attacks.plot(kind="bar",color="cornflowerblue",figsize=(15,6),fontsize=13)
plt.title("Timeline of Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# i. Most number of attacks(16903) in 2014<br>
# ii. Least number of attacks(471) in 1971

# %% [markdown]
# ***We are trying to create a bar plot to visualize the timeline of attacks using the attacks DataFrame.***
#
#
# i.Plotting:
#
# attacks.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), fontsize=13):
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
# + **fontsize=13** - Sets the font size for the text in the plot.
#
# ii.Title and Labels:
#
# + **plt.title("Timeline of Attacks", fontsize=15)** - Sets the title of the plot.
# + **plt.xlabel("Years", fontsize=15)** - Sets the label for the x-axis.
# + **plt.ylabel("Number of Attacks", fontsize=15)** - Sets the label for the y-axis.
#
# iii.Display the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) in each Year

# %%
yc=df[["Year","Casualty"]].groupby("Year").sum()
yc.head()
# Out:
#       Casualty
# Year
# 1970     386.0
# 1971     255.0
# 1972     975.0
# 1973     865.0
# 1974    1404.0

# %% [markdown]
# ***We create a new DataFrame yc that groups the original DataFrame df by the "Year" column and calculates the sum of the "Casualty" column for each year.***
#
# In this code:
#
# + **df[["Year", "Casualty"]]** - Selects only the "Year" and "Casualty" columns from the original DataFrame df.
# + **.groupby("Year")** - Groups the selected DataFrame by the "Year" column.
# + **.sum()** - Calculates the sum of the "Casualty" column for each group (each year).
# + **yc.head()** - Displays the first few rows of the resulting DataFrame yc.

# %%
yc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Year wise Casualties",fontsize=13)
plt.xlabel("Years",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We create a bar plot based on the yc DataFrame, which represents the total casualties for each year.***
#
# i.Plotting:
#
# yc.plot(kind="bar", color="cornflowerblue", figsize=(15, 6))
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Yearwise Casualties", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Years", fontsize=13)** - Sets the label for the x-axis.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.X-axis Tick Font Size:
#
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
#
# iv.Display the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed in each Year

# %%
yk=df[["Year","Killed"]].groupby("Year").sum()
yk.head()
# Out:
#       Killed
# Year
# 1970   174.0
# 1971   173.0
# 1972   566.0
# 1973   370.0
# 1974   539.0

# %% [markdown]
# ***We are creating a new DataFrame yk by grouping the original DataFrame df by the "Year" column and summing up the "Killed" column for each year.***
#
# In this code:
#
# + **df[["Year", "Killed"]]** - Selects only the "Year" and "Killed" columns from the original DataFrame df.
# + **.groupby("Year")** - Groups the selected DataFrame by the "Year" column.
# + **.sum()** - Calculates the sum of the "Killed" column for each group (each year).
# + **yk.head()** - Displays the first few rows of the resulting DataFrame yk.

# %% [markdown]
# + Wounded in each Region

# %%
yw=df[["Year","Wounded"]].groupby("Year").sum()
yw.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    865.0

# %% [markdown]
# ***We are creating a new DataFrame yw by grouping the original DataFrame df by the "Year" column and summing up the "Wounded" column for each year.***
#
# In this code:
#
# + **df[["Year", "Wounded"]]** - Selects only the "Year" and "Wounded" columns from the original DataFrame df.
# + **.groupby("Year")** - Groups the selected DataFrame by the "Year" column.
# + **.sum()** - Calculates the sum of the "Wounded" column for each group (each year).
# + **yw.head()** - Displays the first few rows of the resulting DataFrame yw.

# %%
fig=plt.figure()
ax0=fig.add_subplot(2,1,1)
ax1=fig.add_subplot(2,1,2)

#Killed
yk.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax0)
ax0.set_title("People Killed in each Year")
ax0.set_xlabel("Years")
ax0.set_ylabel("Number of People Killed") 

#Wounded
yw.plot(kind="bar",color="cornflowerblue",figsize=(15,15),ax=ax1)
ax1.set_title("People Wounded in each Year")
ax1.set_xlabel("Years")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# ***We are using Matplotlib to create a figure with two subplots (one for "People Killed" and one for "People Wounded") and then plotting the corresponding DataFrames (yk for killed and yw for wounded) on each subplot.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(2, 1, 1)** - Adds the first subplot (top) for "People Killed."
# + **ax1 = fig.add_subplot(2, 1, 2)** - Adds the second subplot (bottom) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **yk.plot(kind="bar", color="cornflowerblue", figsize=(15, 15), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each Year")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Years")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **yw.plot(kind="bar", color="cornflowerblue", figsize=(15, 15), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each Year")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Years")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***2. Region wise attacks***

# %% [markdown]
# + Distribution of Terrorist Attacks over Regions from 1970-2017

# %%
reg=pd.crosstab(df.Year,df.Region)
reg.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        8                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          28            472
# 1971            1               5                          55            247
# 1972            0               1                          53             73
# 1973            2               1                          19             64
# 1974            4               2                          42            111
#
# ...

# %% [markdown]
# ***We are using the crosstab function from the pandas library to create a contingency table (cross-tabulation) for the "Year" and "Region" columns in DataFrame df. This table shows the frequency of occurrences for each combination of year and region.***
#
# In this code:
#
# + **df.Year** - Specifies the values to be used as rows in the contingency table (in this case, the "Year" column).
# + **df.Region** - Specifies the values to be used as columns in the contingency table (in this case, the "Region" column).
# + **reg.head()** - Displays the first few rows of the resulting contingency table.

# %%
reg.plot(kind="area", stacked=False, alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %% [markdown]
# ***We are using Matplotlib to create an area plot based on the contingency table reg that you created using the crosstab function.***
#
# i.Plotting:
#
# reg.plot(kind="area", stacked=False, alpha=0.5, figsize=(20, 10))
#
# + **kind="area"** - Specifies that an area plot should be created.
# + **stacked=False** - Specifies that the areas should not be stacked on top of each other.
# + **alpha=0.5** - Sets the transparency level of the areas to 0.5 (semi-transparent).
# + **figsize=(20, 10)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Region-wise Attacks", fontsize=20)** - Sets the title of the plot.
# + **plt.xlabel("Years", fontsize=20)** - Sets the label for the x-axis.
# + **plt.ylabel("Number of Attacks", fontsize=20)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Terrorist Attacks in each Region from 1970-2017

# %%
regt=reg.transpose()
regt["Total"]=regt.sum(axis=1)
ra=regt["Total"].sort_values(ascending=False)
ra
# Out:
# Region
# Middle East & North Africa     50474
# South Asia                     44974
# South America                  18978
# Sub-Saharan Africa             17550
# Western Europe                 16639
# Southeast Asia                 12485
# Central America & Caribbean    10344
# Eastern Europe                  5144
# North America                   3456
# East Asia                        802
# Central Asia                     563
# Australasia & Oceania            282
# Name: Total, dtype: int64

# %% [markdown]
# ***We are transposing the contingency table reg using the transpose() function and then calculating the total number of attacks for each region across all years.***
#
# In this code:
#
# + **regt = reg.transpose()** - Transposes the rows and columns of the contingency table, swapping the "Year" and "Region" roles.
# + **regt["Total"] = regt.sum(axis=1)** - Adds a new column "Total" to regt representing the total number of attacks for each region across all years. The sum(axis=1) calculates the sum across each row.
# + **ra = regt["Total"].sort_values(ascending=False)** - Creates a Series (ra) by sorting the regions based on the total number of attacks in descending order (ascending=False).
# + **ra** - Displays the result, which is a Series showing the regions sorted by the total number of attacks in descending order.

# %%
ra.plot(kind="bar",figsize=(15,6))
plt.title("Total Number of Attacks in each Region from 1970-2017")
plt.xlabel("Region")
plt.ylabel("Number of Attacks")
plt.show()

# %% [markdown]
# ***We are using Matplotlib to create a bar plot based on the ra Series, which represents the total number of attacks for each region across all years.***
#
# i.Plotting:
#
# + **ra.plot(kind="bar", figsize=(15, 6))** - Plots the total number of attacks for each region as a bar plot.
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Total Number of Attacks in each Region from 1970-2017")** - Sets the title of the plot.
# + **plt.xlabel("Region")** - Sets the label for the x-axis.
# + **plt.ylabel("Number of Attacks")** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) in each Region

# %%
rc=df[["Region","Casualty"]].groupby("Region").sum().sort_values(by="Casualty",ascending=False)
rc
# Out:
#                              Casualty
# Region
# Middle East & North Africa   351950.0
# South Asia                   242679.0
# Sub-Saharan Africa           131243.0
# South America                 45553.0
# Southeast Asia                41896.0
# Central America & Caribbean   37699.0
# North America                 26447.0
# Western Europe                25026.0
# Eastern Europe                19460.0
# East Asia                     10365.0
# Central Asia                   3009.0
# Australasia & Oceania           410.0

# %% [markdown]
# ***It appears you are creating a new DataFrame rc by grouping the original DataFrame df by the "Region" column and calculating the total casualties for each region. The result is then sorted in descending order based on the total casualties.***
#
# In this code:
#
# + **df[["Region", "Casualty"]].groupby("Region").sum()** - Groups the DataFrame by the "Region" column and calculates the sum of casualties for each region.
# + **.sort_values(by="Casualty", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Casualty" column.
# + **rc** - Displays the resulting DataFrame rc, which shows the total casualties for each region, sorted in descending order.

# %%
rc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Region wise Casualties",fontsize=13)
plt.xlabel("Regions",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***Your code uses Matplotlib to create a bar plot based on the rc DataFrame, which represents the total casualties for each region.***
#
# i.Plotting:
#
# + **rc.plot(kind="bar", color="cornflowerblue", figsize=(15, 6))** - Plots the total casualties for each region as a bar plot.
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Region-wise Casualties", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Regions", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed in each Region

# %%
rk=df[["Region","Killed"]].groupby("Region").sum().sort_values(by="Killed",ascending=False)
rk
# Out:
#                                Killed
# Region
# Middle East & North Africa   137642.0
# South Asia                   101319.0
# Sub-Saharan Africa            78386.0
# South America                 28849.0
# Central America & Caribbean   28708.0
# Southeast Asia                15637.0
# Eastern Europe                 7415.0
# Western Europe                 6694.0
# North America                  4916.0
# East Asia                      1152.0
# Central Asia                   1000.0
# Australasia & Oceania           150.0

# %% [markdown]
# ***We are creating a new DataFrame rk by grouping the original DataFrame df by the "Region" column and calculating the total number of killed for each region. The result is then sorted in descending order based on the total number of killed.***
#
# In this code:
#
# + **df[["Region", "Killed"]].groupby("Region").sum()** - Groups the DataFrame by the "Region" column and calculates the sum of the "Killed" column for each region.
# + **.sort_values(by="Killed", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Killed" column.
# + **rk** - Displays the resulting DataFrame rk, which shows the total number of killed for each region, sorted in descending order.

# %% [markdown]
# + Wounded in each Region

# %%
rw=df[["Region","Wounded"]].groupby("Region").sum().sort_values(by="Wounded",ascending=False)
rw
# Out:
#                               Wounded
# Region
# Middle East & North Africa   214308.0
# South Asia                   141360.0
# Sub-Saharan Africa            52857.0
# Southeast Asia                26259.0
# North America                 21531.0
# Western Europe                18332.0
# South America                 16704.0
# Eastern Europe                12045.0
# East Asia                      9213.0
# Central America & Caribbean    8991.0
# Central Asia                   2009.0
# Australasia & Oceania           260.0

# %% [markdown]
# ***We are creating a new DataFrame rw by grouping the original DataFrame df by the "Region" column and calculating the total number of wounded for each region. The result is then sorted in descending order based on the total number of wounded.***
#
# In this code:
#
# + **df[["Region", "Wounded"]].groupby("Region").sum()** - Groups the DataFrame by the "Region" column and calculates the sum of the "Wounded" column for each region.
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Wounded" column.
# + **rw** - Displays the resulting DataFrame rw, which shows the total number of wounded for each region, sorted in descending order.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
rk.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Region")
ax0.set_xlabel("Regions")
ax0.set_ylabel("Number of People Killed")

#Wounded
rw.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Region")
ax1.set_xlabel("Regions")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded in each region.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **rk.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each Region")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Regions")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **rw.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each Region")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Regions")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***3. Country wise Attacks - Top 10***

# %% [markdown]
# + Number of Attacks in each Country

# %%
ct=df["Country"].value_counts().head(10)
ct
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: Country, dtype: int64

# %% [markdown]
# ***We are using Python pandas to get the top 10 countries based on the frequency of occurrence in a DataFrame column named "Country."***
#
# In this code:
#
# + **df["Country"].value_counts()** - obtain the value counts for the "Country" column
# + **.head(10)** - The .head(10) method is used to get the first 10 rows of the result.
# + **ct** - Displays the result.

# %%
ct.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise Attacks",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We are trying to create a bar plot of the top 10 countries and their counts in the "Country" column using matplotlib.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Country wise Attacks", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Countries", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) in each Country

# %%
cnc=df[["Country","Casualty"]].groupby("Country").sum().sort_values(by="Casualty",ascending=False)
cnc.head(10)
# Out:
#                Casualty
# Country
# Iraq           213279.0
# Afghanistan     83661.0
# Pakistan        65860.0
# India           48321.0
# Nigeria         32921.0
# Sri Lanka       31091.0
# Syria           29338.0
# Colombia        25026.0
# United States   24473.0
# Philippines     22926.0

# %% [markdown]
# ***We are trying to group data by the "Country" column and then sum the "Casualty" values for each country, sorting the result in descending order.***
#
# In this code:
#
# + **df[["Country", "Casualty"]]** - This selects only the "Country" and "Casualty" columns from your DataFrame df.
# + **.groupby("Country").sum()** - This groups the selected columns by the "Country" column and sums up the values for each group.
# + **.sort_values(by="Casualty", ascending=False)** - This sorts the resulting DataFrame based on the "Casualty" column in descending order.
# + **cnc.head(10)** - displays the top 10 rows of the resulting DataFrame.

# %%
cnc[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Country wise Casualties",fontsize=13)
plt.xlabel("Countries",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are trying to create a bar plot based on the top 10 countries with the highest casualties using matplotlib.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Country wise Casualties", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Countries", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed in each Country

# %%
cnk=df[["Country","Killed"]].groupby("Country").sum().sort_values(by="Killed",ascending=False)
cnk.head(10)
# Out:
#               Killed
# Country
# Iraq         78589.0
# Afghanistan  39384.0
# Pakistan     23822.0
# Nigeria      22682.0
# India        19341.0
# Sri Lanka    15530.0
# Syria        15229.0
# Colombia     14698.0
# Peru         12771.0
# El Salvador  12053.0

# %% [markdown]
# ***We are creating a DataFrame cnk by grouping the data based on the "Country" column and then summing up the "Killed" values for each country.***
#
# In this code:
#
# + **df[["Country", "Killed"]]** - Selects only the "Country" and "Killed" columns from your DataFrame df.
# + **.groupby("Country").sum()** - Groups the selected columns by the "Country" column and sums up the "Killed" values for each country.
# + **.sort_values(by="Killed", ascending=False)** - Sorts the resulting DataFrame based on the "Killed" column in descending order.
# + **.head(10)** - Shows the top 10 rows of the resulting DataFrame.

# %% [markdown]
# + Wounded in each Country

# %%
cnw=df[["Country","Wounded"]].groupby("Country").sum().sort_values(by="Wounded",ascending=False)
cnw.head(10)
# Out:
#                 Wounded
# Country
# Iraq           134690.0
# Afghanistan     44277.0
# Pakistan        42038.0
# India           28980.0
# United States   20702.0
# Sri Lanka       15561.0
# Syria           14109.0
# Philippines     13367.0
# Lebanon         10904.0
# Colombia        10328.0

# %% [markdown]
# ***We are creating a DataFrame cnw by grouping the data based on the "Country" column and then summing up the "Wounded" values for each country.***
#
# In this code:
#
# + **df[["Country", "Wounded"]]** - Selects only the "Country" and "Wounded" columns from your DataFrame df.
# + **.groupby("Country").sum()** - Groups the selected columns by the "Country" column and sums up the "Wounded" values for each country.
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame based on the "Wounded" column in descending order.
# + **.head(10)** - Shows the top 10 rows of the resulting DataFrame.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
cnk[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Country")
ax0.set_xlabel("Countries")
ax0.set_ylabel("Number of People Killed")

#Wounded
cnw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Country")
ax1.set_xlabel("Countries")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded in each country.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **cnk[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each Country")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Countries")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **cnw[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each Country")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Countries")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***4. City wise Attacks (Top 10)***

# %% [markdown]
# + Number of Attacks in each city

# %%
city=df["City"].value_counts()[1:11]
city
# Out:
# Baghdad         7589
# Karachi         2652
# Lima            2359
# Mosul           2265
# Belfast         2171
# Santiago        1621
# Mogadishu       1581
# San Salvador    1558
# Istanbul        1048
# Athens          1019
# Name: City, dtype: int64

# %% [markdown]
# ***We are using the value_counts() method to count the occurrences of each unique value in the "City" column and then selecting the top 10 results.***
#
# In this code:
#
# + **df["City"].value_counts()** - This counts the occurrences of each unique value in the "City" column, returning a Series with the counts.
# + **[1:11]** - This slices the Series to select the values from index 1 to index 10 (top 10).

# %%
city.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("City wise Attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We are trying to create a bar plot for a variable named city with information about attacks in different cities using matplotlib.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("City wise Attacks", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Cities", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) in each City

# %%
cc=df[["City","Casualty"]].groupby("City").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
cc.head(10)
# Out:
#                Casualty
# City
# Baghdad         77876.0
# New York City   19619.0
# Mosul           12927.0
# Karachi          9376.0
# Mogadishu        8868.0
# Kabul            8466.0
# Beirut           7257.0
# Kirkuk           6636.0
# Colombo          5906.0
# Aleppo           5748.0

# %% [markdown]
# ***We are creating a DataFrame cc by grouping the data based on the "City" column, summing up the "Casualty" values for each city, sorting the result in descending order, and dropping the rows where the city is labeled as "Unknown.***
#
# In this code:
#
# + **df[["City", "Casualty"]]** - Selects only the "City" and "Casualty" columns from your DataFrame df.
# + **.groupby("City").sum()** - Groups the selected columns by the "City" column and sums up the "Casualty" values for each city.
# + **.sort_values(by="Casualty", ascending=False)** - Sorts the resulting DataFrame based on the "Casualty" column in descending order.
# + **.drop("Unknown")** - Drops rows where the city is labeled as "Unknown."
# + **.head(10)** - Shows the top 10 rows of the resulting DataFrame.

# %%
cc[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("City wise Casualties",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are attempting to create a bar plot for the top 10 cities with the highest casualties.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("City wise Casualties", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Cities", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed in each City

# %%
ck=df[["City","Killed"]].groupby("City").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
ck.head(10)
# Out:
#                 Killed
# City
# Baghdad        21151.0
# Mosul           7140.0
# Mogadishu       3913.0
# Karachi         3688.0
# New York City   2838.0
# Tikrit          2679.0
# Kabul           2493.0
# Ramadi          2313.0
# Maiduguri       2235.0
# Aleppo          2125.0

# %% [markdown]
# ***We are analyzing the total number of people killed for each city in your DataFrame df.***
#
# In this code:
#
# + **df[["City", "Killed"]]** - This selects the "City" and "Killed" columns from the DataFrame df.
# + **.groupby("City").sum()** - This groups the selected columns by "City" and calculates the sum of killed individuals for each city.
# + **.sort_values(by="Killed", ascending=False)** - This sorts the grouped data based on the total number of people killed in each city in descending order.
# + **drop("Unknown")** - This removes entries where the "City" value is "Unknown."
# + **.head(10)** - This selects the top 10 results.

# %% [markdown]
# + Wounded in each City

# %%
cw=df[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
cw.head(10)
# Out:
#                Wounded
# City
# Baghdad        56725.0
# New York City  16781.0
# Kabul           5973.0
# Mosul           5787.0
# Karachi         5688.0
# Tokyo           5542.0
# Beirut          5341.0
# Nairobi         5024.0
# Kirkuk          5008.0
# Mogadishu       4955.0

# %% [markdown]
# ***We are creating a DataFrame cw by grouping the data based on the "City" column, summing up the "Wounded" values for each city, sorting the result in descending order, and dropping the rows where the city is labeled as "Unknown."***
#
# In this code:
#
# + **df[["City", "Wounded"]]** - Selects only the "City" and "Wounded" columns from your DataFrame df.
# + **.groupby("City").sum()** - Groups the selected columns by the "City" column and sums up the "Wounded" values for each city.
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame based on the "Wounded" column in descending order.
# + **.drop("Unknown")** - Drops rows where the city is labeled as "Unknown."
# + **.head(10)** - Shows the top 10 rows of the resulting DataFrame.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
ck[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each City")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of People Killed")

#Wounded
cw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each City")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded in each city.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **ck[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each city")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Cities")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **cw[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each city")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Cities")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***5. Terrorist Group wise Attacks (Top 10)***

# %% [markdown]
# + Number of Attacks by each Group

# %%
grp=df["Group Name"].value_counts()[1:10]
grp
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Name: Group Name, dtype: int64

# %% [markdown]
# ***We are using the value_counts() method to count the occurrences of each unique value in the "Group Name" column and then selecting the top 10 results.***
#
# In this code:
#
# + **df["Group Name"].value_counts()** - This counts the occurrences of each unique value in the "Group Name" column, returning a Series with the counts.
# + **[1:10]** - This slices the Series to select the values from index 1 to index 9 (top 10).

# %%
grp.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Group wise Attacks",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the number of attacks by terrorist groups using the variable grp.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Group wise Attacks", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Terrorist Groups", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties(Killed + Wounded) by each Group

# %%
gc=df[["Group Name","Casualty"]].groupby("Group Name").sum().sort_values(by="Casualty",ascending=False).drop("Unknown")
gc.head(10)
# Out:
#                                                   Casualty
# Group Name
# Islamic State of Iraq and the Levant (ISIL)        69595.0
# Taliban                                            57342.0
# Boko Haram                                         29801.0
# Al-Qaida                                           28372.0
# Liberation Tigers of Tamil Eelam (LTTE)            22020.0
# Al-Shabaab                                         16954.0
# Tehrik-i-Taliban Pakistan (TTP)                    15574.0
# Al-Qaida in Iraq                                   14724.0
# Shining Path (SL)                                  14632.0
# Farabundo Marti National Liberation Front (FMLN)   12130.0

# %% [markdown]
# ***We are working with a DataFrame df and performing operations to analyze and display information related to casualties caused by different terrorist groups.***
#
# In this code:
#
# + **df[["Group Name", "Casualty"]]** - Selects two columns - "Group Name" and "Casualty" from the original DataFrame df.
#
# + **.groupby("Group Name").sum()** - Groups the DataFrame by the "Group Name" column and calculates the sum of the "Casualty" values within each group.
#
# + **.sort_values(by="Casualty", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Casualty" column.
#
# + **.drop("Unknown")** - Drops any rows where the index is "Unknown" from the DataFrame.
#
# + **.head(10)** - Displays the top 10 rows of the resulting DataFrame gc.

# %%
gc.head(10).plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties by each Group",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are trying to create a bar plot for the number of casualties caused by each terrorist group, using the variable gc.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Casualties by each Group", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Terrorist Groups", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed by each Group

# %%
gk=df[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
gk.head(10)
# Out:
#                                                    Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)       38923.0
# Taliban                                           29410.0
# Boko Haram                                        20328.0
# Shining Path (SL)                                 11601.0
# Liberation Tigers of Tamil Eelam (LTTE)           10989.0
# Al-Shabaab                                         9330.0
# Farabundo Marti National Liberation Front (FMLN)   8065.0
# Nicaraguan Democratic Force (FDN)                  6662.0
# Tehrik-i-Taliban Pakistan (TTP)                    6042.0
# Revolutionary Armed Forces of Colombia (FARC)      5661.0

# %% [markdown]
# ***Here we are analyzing the total number of killed individuals for each "Group Name" in your DataFrame df.***
#
# In this code:
#
# + **df[["Group Name", "Killed"]]** - This selects the "Group Name" and "Killed" columns from the DataFrame df.
# + **.groupby("Group Name").sum()** - This groups the selected columns by "Group Name" and calculates the sum of killed individuals for each group.
# + **.sort_values(by="Killed", ascending=False)** - This sorts the grouped data based on the total number of people killed in descending order.
# + **.drop("Unknown")** - This removes entries where the "Group Name" value is "Unknown."
# + **.head(10)** - This selects the top 10 results.

# %% [markdown]
# + Wounded by each Group

# %%
gw=df[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
gw.head(10)
# Out:
#                                              Wounded
# Group Name
# Islamic State of Iraq and the Levant (ISIL)  30672.0
# Taliban                                      27932.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      11031.0
# Al-Qaida in Iraq                             10343.0
# Tehrik-i-Taliban Pakistan (TTP)               9532.0
# Boko Haram                                    9473.0
# Al-Shabaab                                    7624.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4908.0

# %% [markdown]
# ***We are working with a DataFrame df and are analyzing information related to the number of wounded individuals caused by different terrorist groups.***
#
# In this code:
#
# + **df[["Group Name", "Wounded"]]** - Selects two columns - "Group Name" and "Wounded" from the original DataFrame df.
# + **.groupby("Group Name").sum()** - Groups the DataFrame by the "Group Name" column and calculates the sum of the "Wounded" values within each group.
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Wounded" column.
# + **.drop("Unknown")** - Drops any rows where the index is "Unknown" from the DataFrame.
# + **.head(10)** - It shows the top 10 terrorist groups with the highest total number of wounded individuals.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
gk[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed by each Group")
ax0.set_xlabel("Terrorist Groups")
ax0.set_ylabel("Number of people Killed")

#Wounded
gw[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded by each Group")
ax1.set_xlabel("Terrorist Groups")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded by each Terrorist group.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **gk[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed by each Group")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Terrorist Groups")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **gw[:10].plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded by each Group")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Terrorist Groups")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***6. Attack Type wise Attacks***

# %% [markdown]
# + Number of Attacks by each Attack Type

# %%
at=df["Attack Type"].value_counts()
at
# Out:
# Bombing/Explosion                      88255
# Armed Assault                          42669
# Assassination                          19312
# Hostage Taking (Kidnapping)            11158
# Facility/Infrastructure Attack         10356
# Unknown                                 7276
# Unarmed Assault                         1015
# Hostage Taking (Barricade Incident)      991
# Hijacking                                659
# Name: Attack Type, dtype: int64

# %% [markdown]
# ***Here we are using the value_counts() function on the "Attack Type" column in the DataFrame df***
#
# In this code:
#
# + **df["Attack Type"]** - Selects the "Attack Type" column from the DataFrame df.
# + **.value_counts()** - Calculates the frequency of each unique value in the "Attack Type" column.
# + **at** - Contains the counts of each unique attack type in the "Attack Type" column of your DataFrame.

# %%
at.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Attacks",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We arecreating a bar plot for the types of attacks using the variable at.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Types of Attacks", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Attack Types", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) by each Attack Type

# %%
ac=df[["Attack Type","Casualty"]].groupby("Attack Type").sum().sort_values(by="Casualty",ascending=False)
ac
# Out:
#                                      Casualty
# Attack Type
# Bombing/Explosion                    530007.0
# Armed Assault                        237663.0
# Unknown                               47106.0
# Assassination                         38807.0
# Hostage Taking (Kidnapping)           30677.0
# Hijacking                             20719.0
# Unarmed Assault                       14907.0
# Hostage Taking (Barricade Incident)    8444.0
# Facility/Infrastructure Attack         7407.0

# %% [markdown]
# ***We are working with a DataFrame named df and trying to perform some operations on it, specifically focusing on the columns "Attack Type" and "Casualty".***
#
# In this code:
#
# + **df[["Attack Type", "Casualty"]]** - This selects only the "Attack Type" and "Casualty" columns from the DataFrame df.
# + **.groupby("Attack Type").sum()** - This groups the selected columns by the "Attack Type" and calculates the sum of casualties for each attack type.
# + **.sort_values(by="Casualty", ascending=False)** - This sorts the grouped data based on the total casualties in descending order.
# + **ac** - Contain a DataFrame with the total casualties for each attack type.

# %%
ac.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in each Attack",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the number of casualties in each attack type using the variable ac.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Casualties in each Attack", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Attack Types", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed by each Attack Type

# %%
ak=df[["Attack Type","Killed"]].groupby("Attack Type").sum().sort_values(by="Killed",ascending=False)
ak
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        160297.0
# Bombing/Explosion                    157321.0
# Unknown                               32381.0
# Assassination                         24920.0
# Hostage Taking (Kidnapping)           24231.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3642.0
# Unarmed Assault                         880.0

# %% [markdown]
# ***We are analyzing the total number of people killed for each attack type in your DataFrame df.***
#
# In this code:
#
# + **df[["Attack Type", "Killed"]]** - This selects the "Attack Type" and "Killed" columns from the DataFrame df.
# + **.groupby("Attack Type").sum()** - This groups the selected columns by "Attack Type" and calculates the sum of killed individuals for each attack type.
# + **.sort_values(by="Killed", ascending=False)** - This sorts the grouped data based on the total number of people killed in descending order.
# + **ak** - It contains a DataFrame with the total number of people killed for each attack type.

# %% [markdown]
# + Wounded by each Attack Type

# %%
aw=df[["Attack Type","Wounded"]].groupby("Attack Type").sum().sort_values(by="Wounded",ascending=False)
aw
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    372686.0
# Armed Assault                         77366.0
# Hijacking                             17001.0
# Unknown                               14725.0
# Unarmed Assault                       14027.0
# Assassination                         13887.0
# Hostage Taking (Kidnapping)            6446.0
# Hostage Taking (Barricade Incident)    3966.0
# Facility/Infrastructure Attack         3765.0

# %% [markdown]
# ***We are creating a DataFrame aw by grouping the data based on the "Attack Type" column, summing up the "Wounded" values for each attack type, and sorting the result in descending order.***
#
# In this code:
#
# + **df[["Attack Type", "Wounded"]]** - Selects only the "Attack Type" and "Wounded" columns from your DataFrame df.
# + **.groupby("Attack Type").sum()** - Groups the selected columns by the "Attack Type" column and sums up the "Wounded" values for each attack type.
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame based on the "Wounded" column in descending order.
# + **aw** - Displays the resulting DataFrame aw, which shows the total number of wounded for each attack type, sorted in descending order.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
ak.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Attack Type")
ax0.set_xlabel("Attack Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
aw.plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Attack Type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded in each Attack Type.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **ak.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each Attack Type")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Attack Types")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **aw.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each Attack Type")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Attack Types")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***7. Target Type wise Attacks***

# %% [markdown]
# + Number of Attacks over each Target Type

# %%
ta=df["Target Type"].value_counts()
ta
# Out:
# Private Citizens & Property       43511
# Military                          27984
# Police                            24506
# Government (General)              21283
# Business                          20669
# Transportation                     6799
# Utilities                          6023
# Unknown                            5898
# Religious Figures/Institutions     4440
# Educational Institution            4322
# Government (Diplomatic)            3573
# Terrorists/Non-State Militia       3039
# Journalists & Media                2948
# Violent Political Party            1866
# Airports & Aircraft                1343
# Telecommunication                  1009
# NGO                                 970
# Tourists                            440
# Maritime                            351
# Food or Water Supply                317
# Abortion Related                    263
# Other                               137
# Name: Target Type, dtype: int64

# %% [markdown]
# ***We are using the value_counts() function on the "Target Type" column in the DataFrame df. This will provide a count of unique values in the "Target Type" column.***
#
# In this code:
#
# + **df["Target Type"]** - Selects the "Target Type" column from the DataFrame df.
# + **.value_counts()** - Calculates the frequency of each unique value in the "Target Type" column.
# + **ta** - This will display the counts of each target type in the "Target Type" column of your DataFrame.

# %%
ta.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Types of Targets",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the types of targets using the variable ta.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Types of Targets", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Target Types", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Total Casualties (Killed + Wounded) by each Target Type

# %%
tc=df[["Target Type","Casualty"]].groupby("Target Type").sum().sort_values(by="Casualty",ascending=False)
tc
# Out:
#                                 Casualty
# Target Type
# Private Citizens & Property     319176.0
# Military                        177085.0
# Police                          118407.0
# Business                         78018.0
# Government (General)             67255.0
# Transportation                   54595.0
# Religious Figures/Institutions   37890.0
# Terrorists/Non-State Militia     17311.0
# Educational Institution          13972.0
# Government (Diplomatic)          13398.0
# Violent Political Party           8920.0
# Unknown                           7888.0
# Airports & Aircraft               7245.0
# Journalists & Media               3297.0
# Utilities                         3227.0
# Maritime                          2099.0
# Tourists                          2048.0
# NGO                               1950.0
# Telecommunication                  679.0
# Other                              674.0
# Food or Water Supply               547.0
# ...

# %% [markdown]
# ***We are creating a DataFrame named tc by grouping the data from the "Target Type" column and calculating the sum of casualties for each type.***
#
# In this code:
#
# + **df[["Target Type", "Casualty"]]** - This selects only the "Target Type" and "Casualty" columns from the DataFrame df.
# + **.groupby("Target Type").sum()** - This groups the selected columns by the "Target Type" and calculates the sum of casualties for each target type.
# + **.sort_values(by="Casualty", ascending=False)** - This sorts the grouped data based on the total casualties in descending order.
# + **tc** - Contain a DataFrame with the total casualties for each target type

# %%
tc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Casualties in each Target Attack",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the number of casualties in each target type attack using the variable tc.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Casualties in each Target Attack", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Target Types", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Killed by each Target Type

# %%
tk=df[["Target Type","Killed"]].groupby("Target Type").sum().sort_values(by="Killed",ascending=False)
tk
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     140504.0
# Military                        106047.0
# Police                           53704.0
# Government (General)             26071.0
# Business                         23487.0
# Transportation                   13916.0
# Religious Figures/Institutions   13413.0
# Terrorists/Non-State Militia      9088.0
# Unknown                           4329.0
# Airports & Aircraft               3767.0
# Educational Institution           3745.0
# Violent Political Party           3617.0
# Government (Diplomatic)           3039.0
# Utilities                         1874.0
# Journalists & Media               1501.0
# Maritime                          1191.0
# NGO                               1057.0
# Tourists                           758.0
# Food or Water Supply               313.0
# Other                              255.0
# Telecommunication                  182.0
# ...

# %% [markdown]
# ***We are analyzing the total number of people killed for each target type in your DataFrame df.***
#
# In this code:
#
# + **df[["Target Type", "Killed"]]** - This selects the "Target Type" and "Killed" columns from the DataFrame df.
# + **.groupby("Target Type").sum()** - This groups the selected columns by "Target Type" and calculates the sum of killed individuals for each target type.
# + **.sort_values(by="Killed", ascending=False)** - This sorts the grouped data based on the total number of people killed for each target type in descending order.
# + **tk** - It contains a DataFrame with the total number of people killed for each target type.

# %% [markdown]
# + Wounded by each Target Type

# %%
tw=df[["Target Type","Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded",ascending=False)
tw
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     178672.0
# Military                         71038.0
# Police                           64703.0
# Business                         54531.0
# Government (General)             41184.0
# Transportation                   40679.0
# Religious Figures/Institutions   24477.0
# Government (Diplomatic)          10359.0
# Educational Institution          10227.0
# Terrorists/Non-State Militia      8223.0
# Violent Political Party           5303.0
# Unknown                           3559.0
# Airports & Aircraft               3478.0
# Journalists & Media               1796.0
# Utilities                         1353.0
# Tourists                          1290.0
# Maritime                           908.0
# NGO                                893.0
# Telecommunication                  497.0
# Other                              419.0
# Food or Water Supply               234.0
# ...

# %% [markdown]
# ***We are analyzing the total number of people wounded for each target type in your DataFrame df.***
#
# In this code:
#
# + **df[["Target Type", "Wounded"]]** - This selects the "Target Type" and "Wounded" columns from the DataFrame df.
# + **.groupby("Target Type").sum()** - This groups the selected columns by "Target Type" and calculates the sum of wounded individuals for each target type.
# + **.sort_values(by="Wounded", ascending=False)** - This sorts the grouped data based on the total number of people wounded for each target type in descending order.
# + **tw** - It contains a DataFrame with the total number of people wounded for each target type.

# %%
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
tk.plot(kind="bar",color="cornflowerblue",figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Target Attack")
ax0.set_xlabel("Target Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
tw.plot(kind="bar",color="cornflowerblue",figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Target Attack")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ***This code is creating a figure with two subplots (side by side) and plotting bar plots for the number of people killed and wounded in each Target Attack.***
#
# i.Creating the Figure and Subplots:
#
# + **fig = plt.figure()** - Creates a new figure.
# + **ax0 = fig.add_subplot(1, 2, 1)** - Adds the first subplot (left) for "People Killed."
# + **ax1 = fig.add_subplot(1, 2, 2)** - Adds the second subplot (right) for "People Wounded."
#
# ii.Plotting for People Killed:
#
# + **tk.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax0)** - Plots the "People Killed" data on the first subplot.
# + **ax0.set_title("People Killed in each Target Attack")** - Sets the title for the first subplot.
# + **ax0.set_xlabel("Target Types")** - Sets the x-axis label for the first subplot.
# + **ax0.set_ylabel("Number of People Killed")** - Sets the y-axis label for the first subplot.
#
# iii.Plotting for People Wounded:
#
# + **tw.plot(kind="bar", color="cornflowerblue", figsize=(15, 6), ax=ax1)** - Plots the "People Wounded" data on the second subplot.
# + **ax1.set_title("People Wounded in each Target Attack")** - Sets the title for the second subplot.
# + **ax1.set_xlabel("Target Types")** - Sets the x-axis label for the second subplot.
# + **ax1.set_ylabel("Number of People Wounded")** - Sets the y-axis label for the second subplot.
#
# iv.Displaying the Figure:
#
# + **plt.show()** - Displays the entire figure with both subplots.

# %% [markdown]
# ***8. Group + Country wise (Top10)***

# %% [markdown]
# + Sorting by number of Attack

# %%
gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
gca.head(10)
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_11348\390661980.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gca=df[["Group Name","Country"]].value_counts().drop("Unknown")
# Group Name                                        Country
# Taliban                                           Afghanistan       7423
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4797
# Shining Path (SL)                                 Peru              4541
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       3330
# Al-Shabaab                                        Somalia           2867
# New People's Army (NPA)                           Philippines       2770
# Irish Republican Army (IRA)                       United Kingdom    2575
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2468
# Kurdistan Workers' Party (PKK)                    Turkey            2109
# ...

# %% [markdown]
# ***Here we are trying to count the occurrences of each combination of "Group Name" and "Country" in your DataFrame df, excluding those with the "Unknown" value in the "Country" column. The result is stored in a Series named gca, and we are displaying the top 10 results.***
#
# In this code:
#
# + **df[["Group Name", "Country"]]** - This selects only the "Group Name" and "Country" columns from the DataFrame df.
# + **.value_counts()** - This counts the occurrences of each unique combination of "Group Name" and "Country."
# + **.drop("Unknown")** - This removes the entries where the "Country" value is "Unknown".
# + **gca.head(10)** - It should display the top 10 results of the gca Series, showing the counts for each combination of "Group Name" and "Country" (excluding "Unknown").

# %%
gca.head(10).plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Countries with most attacks by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the top 10 countries with the most attacks by a particular terrorist group using the variable gca.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Countries with most attacks by a particular Group", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("Terrorist Group,Country", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Attacks", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Sorting by Number of Casualties

# %%
gcc=df[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(10)
gcc
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_11348\2668093037.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcc=df[["Group Name","Country","Casualty"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Casualty",ascending=False).drop("Unknown").head(10)
#                                                                 Casualty
# Group Name                                       Country
# Taliban                                          Afghanistan     57140.0
# Islamic State of Iraq and the Levant (ISIL)      Iraq            54755.0
# Boko Haram                                       Nigeria         24588.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka       21919.0
# Al-Qaida                                         United States   19494.0
# Tehrik-i-Taliban Pakistan (TTP)                  Pakistan        15532.0
# ...

# %% [markdown]
# ***We are extending our analysis to include the total casualties for each combination of "Group Name" and "Country." The resulting DataFrame, named 'gcc', seems to display the top 10 combinations sorted by total casualties, excluding those with "Unknown" in the "Country" column.***
#
# In this code:
#
# + **df[["Group Name", "Country", "Casualty"]]** - This selects the relevant columns from the DataFrame df.
# + **.groupby(["Group Name", "Country"], axis=0).sum()** - This groups the selected columns by "Group Name" and "Country" and calculates the sum of casualties for each combination.
# + **.sort_values(by="Casualty", ascending=False)** - This sorts the grouped data based on the total casualties in descending order.
# + **.drop("Unknown")** - This removes entries where the "Country" value is "Unknown."
# + **.head(10)** - This selects the top 10 results.

# %%
gcc.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Countries with most casualties by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Casualties",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the countries with the most casualties caused by a particular terrorist group using the variable gcc.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Countries with most casualties by a particular Group", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("(Terrorist Group,Country)", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of Casualties", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Sorting by Number of People Killed

# %%
gck=df[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
gck
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_11348\3452644615.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gck=df[["Group Name","Country","Killed"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Killed",ascending=False).drop("Unknown").head(10)
#                                                                Killed
# Group Name                                       Country
# Islamic State of Iraq and the Levant (ISIL)      Iraq         31058.0
# Taliban                                          Afghanistan  29269.0
# Boko Haram                                       Nigeria      16917.0
# Shining Path (SL)                                Peru         11595.0
# Liberation Tigers of Tamil Eelam (LTTE)          Sri Lanka    10928.0
# Al-Shabaab                                       Somalia       8176.0
# Farabundo Marti National Liberation Front (FMLN) El Salvador   8019.0
# ...

# %% [markdown]
# ***We are performing operations on a DataFrame df to analyze and display information related to the number of people killed by terrorist groups in different countries.***
#
# In this code:
#
# + **df[["Group Name", "Country", "Killed"]]** - Selects three columns - "Group Name," "Country," and "Killed" from the original DataFrame df.
# + **.groupby(["Group Name", "Country"], axis=0).sum()** - Groups the DataFrame by both "Group Name" and "Country" and calculates the sum of the "Killed" values within each group. The axis=0 specifies that the grouping is done along the rows.
# + **.sort_values(by="Killed", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Killed" column.
# + **.drop("Unknown")** - Drops any rows where the index is "Unknown" from the DataFrame.
# + **.head(10)** - It shows the top 10 groups and countries with the highest total number of killed individuals.

# %%
gck.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Countries with most people killed by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Killed",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the countries with the most people killed by a particular terrorist group using the variable gck.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Countries with most people killed by a particular Group", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("(Terrorist Group,Country)", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of people Killed", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# + Sorting by Number of People Wounded

# %%
gcw=df[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
gcw
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_11348\1046759477.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   gcw=df[["Group Name","Country","Wounded"]].groupby(["Group Name","Country"],axis=0).sum().sort_values(by="Wounded",ascending=False).drop("Unknown").head(10)
#                                                            Wounded
# Group Name                                  Country
# Taliban                                     Afghanistan    27871.0
# Islamic State of Iraq and the Levant (ISIL) Iraq           23697.0
# Al-Qaida                                    United States  16493.0
# Liberation Tigers of Tamil Eelam (LTTE)     Sri Lanka      10991.0
# Al-Qaida in Iraq                            Iraq           10075.0
# Tehrik-i-Taliban Pakistan (TTP)             Pakistan        9518.0
# Boko Haram                                  Nigeria         7671.0
# ...

# %% [markdown]
# ***We are performing some operations on a DataFrame df to analyze and display information related to wounded individuals caused by terrorist groups in different countries.***
#
# In this code:
#
# + **df[["Group Name", "Country", "Wounded"]]** - Selects three columns - "Group Name," "Country," and "Wounded" from the original DataFrame df.
#
# + **.groupby(["Group Name", "Country"], axis=0).sum()** - Groups the DataFrame by both "Group Name" and "Country" and calculates the sum of the "Wounded" values within each group. The axis=0 specifies that the grouping is done along the rows.
#
# + **.sort_values(by="Wounded", ascending=False)** - Sorts the resulting DataFrame in descending order based on the "Wounded" column.
#
# + **.drop("Unknown")** - Drops any rows where the index is "Unknown" from the DataFrame.
#
# + **.head(10)** - Displays the top 10 rows of the resulting DataFrame gcw.

# %%
gcw.plot(kind="bar",color="cornflowerblue",figsize=(15,6))
plt.title("Countries with most people wounded by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of people Wounded",fontsize=13)
plt.show()

# %% [markdown]
# ***We are creating a bar plot for the countries with the most people wounded by a particular terrorist group using the variable gcw.***
#
# i.Plotting:
#
# + **kind="bar"** - Specifies that a bar plot should be created.
# + **color="cornflowerblue"** - Sets the color of the bars to cornflower blue.
# + **figsize=(15, 6)** - Specifies the size of the figure (width, height) in inches.
#
# ii.Title and Labels:
#
# + **plt.title("Countries with most people wounded by a particular Group", fontsize=13)** - Sets the title of the plot.
# + **plt.xlabel("(Terrorist Group,Country)", fontsize=13)** - Sets the label for the x-axis.
# + **plt.xticks(fontsize=12)** - Sets the font size for the x-axis ticks.
# + **plt.ylabel("Number of people Wounded", fontsize=13)** - Sets the label for the y-axis.
#
# iii.Displaying the Plot:
#
# + **plt.show()** - Displays the plot.

# %% [markdown]
# ***9. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017***

# %% [markdown]
# + Total Casualties (Killed + Wounded) due to Terrorist Attacks

# %%
casualty=df.loc[:,"Casualty"].sum()
print("Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :\n",casualty)
# Out:
# Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world :
#  935737.0

# %% [markdown]
# + Killed due to Terrorist Attacks

# %%
kill=df.loc[:,"Killed"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",kill)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  411868.0

# %% [markdown]
# + Wounded due to Terrorist Attacks

# %%
wound=df.loc[:,"Wounded"].sum()
print("Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :\n",wound)
# Out:
# Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world :
#  523869.0

# %% [markdown]
# ## Observations

# %% [markdown]
# ***1.Year wise Attacks***
#
#    i.Attacks
#
#    + Most number of attacks: **16903 in 2014**
#    + Least number of attacks: **471 in 1971**
#
#    ii.Casualties
#
#    + Most number of casualties: **85618 in 2014**
#    + Least number of casualties: **255 in 1971**
#
#    iii.Killed
#
#    + Most number of people killed: **44490 in 2014**
#    + Least number of people killed: **173 in 1971**
#
#    iv.Wounded
#
#    + Most number of people wounded: **44043 in 2015**
#    + Least number of people wounded: **82 in 1971**

# %% [markdown]
# ***2.Region wise Attacks***
#
#    i.Attacks
#
#    + Most number of attacks: **50474 in "Middle East & North Africa"**
#    + Least number of attacks: **282 in "Australasia & Oceania"**
#
#    ii.Casualties
#
#    + Most number of casualties: **351950 in "Middle East & North Africa"**
#    + Least number of casualties: **410 in Australasia & Oceania**
#
#    iii.Killed
#
#    + Most number of people killed: **137642 in "Middle East & North Africa"**
#    + Least number of people killed: **150 in "Australasia & Oceania"**
#
#    iv.Wounded
#
#    + Most number of people wounded: **214308 in "Middle East & North Africa"**
#    + Least number of people wounded: **260 in "Australasia & Oceania"**

# %% [markdown]
# ***3.Country wise Attacks (Top 10)***
#
#    i.Attacks
#
#    + Most number of attacks: **24636 in "Iraq"**
#    + Least number of attacks: **4292 in "Turkey"**
#
#    ii.Casualties
#
#    + Most number of casualties: **213279 in "Iraq"**
#    + Least number of casualties: **22926 in "Philippines"**
#
#    iii.Killed
#
#    + Most number of people killed: **78589 in "Iraq"**
#    + Least number of people killed: **12053 in "El Salvador"**
#
#    iv.Wounded
#
#    + Most number of people wounded: **134690 in "Iraq"**
#    + Least number of people wounded: **10328 in "Colombia"**

# %% [markdown]
# ***4.City wise Attacks (Top 10)***
#
#    i.Attacks
#
#    + Most number of attacks: **7589 in "Baghdad"**
#    + Least number of attacks: **1019 in "Athens"**
#
#    ii.Casualties
#
#    + Most number of casualties: **77876 in "Baghdad"**
#    + Least number of casualties: **5748 in "Aleppo"**
#
#    iii.Killed
#
#    + Most number of people killed: **21151 in "Baghdad"**
#    + Least number of people killed: **2125 in "Aleppo"**
#
#    iv.Wounded
#
#    + Most number of people wounded: **56725 in "Baghdad"**
#    + Least number of people wounded: **4955 in "Mogadishu"**

# %% [markdown]
# ***5.Terrorist Group Attacks (Top 10)***
#
#    i.Attacks
#
#    + Most number of attacks : **7478 by "Taliban"**
#    + Least number of attacks : **2418 by "Boko Haram"**
#
#    ii.Casualties
#
#    + Most number of casualties : **69595 by "Islamic State of Iraq and the Levant (ISIL)"**
#    + Least number of casualties : **12130 by "Farabundo Marti National Liberation Front (FMLN)"**
#
#    iii.Killed
#
#    + Most number of people killed : **38923 by "Islamic State of Iraq and the Levant (ISIL)"**
#    + Least number of people killed : **5661 by "Revolutionary Armed Forces of Colombia (FARC)"**
#
#    iv.Wounded
#
#    + Most number of people wounded : **30672 by "Islamic State of Iraq and the Levant (ISIL)"**
#    + Least number of people wounded : **4908 by "Kurdistan Workers' Party (PKK)"**

# %% [markdown]
# ***6.Attack Type wise Attacks***
#
#    i.Attacks
#
#    + Most number of attacks : **88255 by "Bombing/Explosion"**
#    + Least number of attacks : **659 by "Hijacking"**
#
#    ii.Casualties
#
#    + Most number of casualties : **530007 by "Bombing/Explosion"**
#    + Least number of casualties : **7407 by "Facility/Infrastructure Attack"**
#
#    iii.Killed
#
#    + Most number of people killed : **160297 by "Armed Assault"**
#    + Least number of people killed : **880 by "Unarmed Assault"**
#
#    iv.Wounded
#
#    + Most number of people wounded : **372686 by "Bombing/Explosion"**
#    + Least number of people wounded : **3765 by "Facility/Infrastructure Attack"**

# %% [markdown]
# ***7.Target Type wise Attacks***
#
#    i.Attacks
#
#    + Most number of attacks : **43511 over "Private Citizens & Property"**
#    + Least number of attacks : **263 over "Abortion Related"**
#
#    ii.Casualties
#
#    + Most number of casualties : **319176 over "Private Citizens & Property"**
#    + Least number of casualties : **56 over "Abortion Related"**
#
#    iii.Killed
#
#    + Most number of people killed : **140504 over "Private Citizens & Property"**
#    + Least number of people killed : **10 over "Abortion Related"**
#
#    iv.Wounded
#
#    + Most number of people wounded : **178672 over "Private Citizens & Property"**
#    + Least number of people wounded : **46 over "Abortion Related"**

# %% [markdown]
# ***8.Group and Country wise Attacks (Top 10)***
#
#    i.Attacks
#
#    + Most number of attacks : **7423 by "Taliban" in "Afghanistan"**
#    + Least number of attacks : **2087 by "Boko Haram" in "Nigeria"**
#
#    ii.Casualties
#
#    + Most number of casualties : **57140 by "Taliban" in "Afghanistan"**
#    + Least number of casualties : **12068 by "Farabundo Marti National Liberation Front (FMLN)"	in "El Salvador"**
#
#    iii.Killed
#
#    + Most number of people killed : **31058 by "Islamic State of Iraq and the Levant (ISIL)" in "Iraq"**
#    + Least number of people killed : **6014 by "Tehrik-i-Taliban Pakistan (TTP)" in "Pakistan"**
#
#    iv.Wounded
#
#    + Most number of people wounded : **27871 by "Taliban" in "Afghanistan"**
#    + Least number of people wounded : **4795 by "Kurdistan Workers' Party (PKK)" in "Turkey"**

# %% [markdown]
# ***9. Humanity Affected (World-wide) by Terrorist Attacks from 1970 to 2017***
#
#    i. Total number of Casualties due to Terrorist Attacks from 1970 to 2017 across the world : **935737** <br>
#    ii. Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : **411868** <br>
#    iii. Total number of people killed due to Terrorist Attacks from 1970 to 2017 across the world : **523869**
